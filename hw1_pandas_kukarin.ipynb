# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/movies.csv').merge(pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ratings.csv'), on='movieId', how="left")
df[df['rating']==5.0]['title'].value_counts().head(1)
# Out:
# title
# Shawshank Redemption, The (1994)    153
# Name: count, dtype: int64

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/power.csv')
baltic_power = df[(df['country'].isin(['Lithuania', 'Latvia', 'Estonia'])) & (df['category'].isin([4, 12, 21])) & (df['year'] > 2005) & (df['year'] < 2010) & (df['quantity'] > 0)]
baltic_power['quantity'].sum()
# Out:
# 164555.0

# %%
df = pd.read_html('https://pythonworld.ru/tipy-dannyx-v-python/stroki-funkcii-i-metody-strok.html')[0]
df
# Out:
#                                     Функция или метод  \
# 0   S = 'str'; S = "str"; S = '''str'''; S = """st...
# 1                                  S = "s\np\ta\nbbb"
# 2                                  S = r"C:\temp\new"
# 3                                         S = b"byte"
# 4                                             S1 + S2
# 5                                              S1 * 3
# 6                                                S[i]
# 7                                         S[i:j:step]
# 8                                              len(S)
# 9                          S.find(str, [start],[end])
# 10                        S.rfind(str, [start],[end])
# 11                        S.index(str, [start],[end])
# 12                       S.rindex(str, [start],[end])
# 13              S.replace(шаблон, замена[, maxcount])
# 14                                    S.split(символ)
# 15                                        S.isdigit()
# ...
