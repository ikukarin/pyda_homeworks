# %%
from datetime import datetime
from datetime import timedelta

The_Moscow_Times = 'Wednesday, October 2, 2002'
The_Guardian = 'Friday, 11.10.13'
Daily_News = 'Thursday, 18 August 1977'

dt_mt = datetime.strptime(The_Moscow_Times, '%A, %B %d, %Y')
print(dt_mt)

dt_g = datetime.strptime(The_Guardian, '%A, %d.%m.%y')
print(dt_g)

dt_dn = datetime.strptime(Daily_News, '%A, %d %B %Y')
print(dt_dn)
# Out:
# 2002-10-02 00:00:00
# 2013-10-11 00:00:00
# 1977-08-18 00:00:00

# %%
stream = ['2018-04-20', '2018-02-29', '2018-19-02']


def is_date_correct(dt):
    try:
        datetime.strptime(dt, '%Y-%m-%d')
        return True
    except ValueError:
        return False


for date in stream:
    print(is_date_correct(date))
# Out:
# True
# False
# False

# %%
dates = []
start_date = input('Введите начальную дату: ')
end_date = input('Введите конечную дату: ')


def date_range():
    try:
        start_dt = datetime.strptime(start_date, '%Y-%m-%d')
        end_dt = datetime.strptime(end_date, '%Y-%m-%d')
        current_dt = start_dt
        if start_dt > end_dt:
            return dates
        else:
            while current_dt <= end_dt:
                dates.append(current_dt.strftime('%Y-%m-%d'))
                current_dt += timedelta(days=1)
            return dates
    except ValueError:
        return dates


print(date_range())
# Out:
# Введите начальную дату: 2024-12-31
# Введите конечную дату: 2024-12-12
# []
